# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("../Data/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_disposition','koi_impact','koi_duration','koi_depth','koi_prad','koi_teq','koi_insol','koi_model_snr']]
selected_features = selected_features[selected_features['koi_disposition']!='CANDIDATE']
selected_features
# Out:
#      koi_disposition  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 0          CONFIRMED       0.586       4.50700      874.8      2.83      443
# 1     FALSE POSITIVE       0.969       1.78220    10829.0     14.60      638
# 2     FALSE POSITIVE       1.276       2.40641     8079.2     33.46     1395
# 3          CONFIRMED       0.701       1.65450      603.3      2.75     1406
# 4          CONFIRMED       0.762       3.14020      686.0      2.77     1160
# ...              ...         ...           ...        ...       ...      ...
# 6983  FALSE POSITIVE       2.441      77.98300     1583.8    534.47     1006
# 6986  FALSE POSITIVE       0.765       4.80600       87.7      1.11      929
# 6987  FALSE POSITIVE       1.252       3.22210     1579.2     29.35     2088
# 6989  FALSE POSITIVE       0.147       0.86500      103.6      1.07     2218
# 6990  FALSE POSITIVE       0.134       3.07800       76.7      1.05     1266
#
#       koi_insol  koi_model_snr
# 0          9.11           25.8
# 1         39.30           76.3
# 2        891.96          505.6
# 3        926.16           40.9
# 4        427.65           40.2
# ...         ...            ...
# 6983     242.54          171.5
# 6986     176.40            8.4
# 6987    4500.53          453.3
# 6989    5713.41           12.3
# 6990     607.42            8.2
#
# [5304 rows x 8 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X = selected_features[['koi_impact','koi_duration','koi_depth','koi_prad','koi_teq','koi_insol','koi_model_snr']]
y = selected_features['koi_disposition']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
y_train
# Out:
# 4608    FALSE POSITIVE
# 2644         CONFIRMED
# 1322    FALSE POSITIVE
# 460          CONFIRMED
# 2579         CONFIRMED
#              ...
# 3527    FALSE POSITIVE
# 3587    FALSE POSITIVE
# 3690    FALSE POSITIVE
# 2116         CONFIRMED
# 2822    FALSE POSITIVE
# Name: koi_disposition, Length: 3978, dtype: object

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import MinMaxScaler
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(C=50, max_iter=100, tol=0.00001)

model.fit(X_train_scaled, y_train)
# Out:
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=50, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=1e-05, verbose=0,
#                    warm_start=False)

# %%
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.7639517345399698
# Testing Data Score: 0.7812971342383107

# %%
predictions = model.predict(X_test_scaled)

pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#           Prediction          Actual
# 1290  FALSE POSITIVE  FALSE POSITIVE
# 1395  FALSE POSITIVE       CONFIRMED
# 5788  FALSE POSITIVE  FALSE POSITIVE
# 4864  FALSE POSITIVE  FALSE POSITIVE
# 4969       CONFIRMED  FALSE POSITIVE
# ...              ...             ...
# 5323  FALSE POSITIVE  FALSE POSITIVE
# 4158  FALSE POSITIVE  FALSE POSITIVE
# 821        CONFIRMED       CONFIRMED
# 5175  FALSE POSITIVE  FALSE POSITIVE
# 5446  FALSE POSITIVE  FALSE POSITIVE
#
# [1326 rows x 2 columns]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50],
              'max_iter': [10, 100, 1000],
            'tol':[0.00001, 0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV] C=1, max_iter=10, tol=1e-05 .....................................
# [CV] ......... C=1, max_iter=10, tol=1e-05, score=0.741, total=   0.0s
# [CV] C=1, max_iter=10, tol=1e-05 .....................................
# [CV] ......... C=1, max_iter=10, tol=1e-05, score=0.762, total=   0.0s
# [CV] C=1, max_iter=10, tol=1e-05 .....................................
# [CV] ......... C=1, max_iter=10, tol=1e-05, score=0.753, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.0001 ....................................
# [CV] ........ C=1, max_iter=10, tol=0.0001, score=0.741, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.0001 ....................................
# [CV] ........ C=1, max_iter=10, tol=0.0001, score=0.762, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.0001 ....................................
# [CV] ........ C=1, max_iter=10, tol=0.0001, score=0.753, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.001 .....................................
# [CV] ......... C=1, max_iter=10, tol=0.001, score=0.741, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.001 .....................................
# [CV] ......... C=1, max_iter=10, tol=0.001, score=0.762, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.001 .....................................
# [CV] ......... C=1, max_iter=10, tol=0.001, score=0.753, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.01 ......................................
# [CV] .......... C=1, max_iter=10, tol=0.01, score=0.742, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.01 ......................................
# [CV] .......... C=1, max_iter=10, tol=0.01, score=0.762, total=   0.0s
# [CV] C=1, max_iter=10, tol=0.01 ......................................
# [CV] .......... C=1, max_iter=10, tol=0.01, score=0.753, total=   0.0s
# [CV] C=1, max_iter=100, tol=1e-05 ....................................
# [CV] ........ C=1, max_iter=100, tol=1e-05, score=0.741, total=   0.0s
# [CV] C=1, max_iter=100, tol=1e-05 ....................................
# [CV] ........ C=1, max_iter=100, tol=1e-05, score=0.762, total=   0.0s
# [CV] C=1, max_iter=100, tol=1e-05 ....................................
# [CV] ........ C=1, max_iter=100, tol=1e-05, score=0.753, total=   0.0s
# [CV] C=1, max_iter=100, tol=0.0001 ...................................
# [CV] ....... C=1, max_iter=100, tol=0.0001, score=0.741, total=   0.0s
# [CV] C=1, max_iter=100, tol=0.0001 ...................................
# [CV] ....... C=1, max_iter=100, tol=0.0001, score=0.762, total=   0.0s
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] C=1, max_iter=100, tol=0.0001 ...................................
# [CV] ....... C=1, max_iter=100, tol=0.0001, score=0.753, total=   0.0s
# [CV] C=1, max_iter=100, tol=0.001 ....................................
# [CV] ........ C=1, max_iter=100, tol=0.001, score=0.741, total=   0.0s
# [CV] C=1, max_iter=100, tol=0.001 ....................................
# [CV] ........ C=1, max_iter=100, tol=0.001, score=0.762, total=   0.0s
# [CV] C=1, max_iter=100, tol=0.001 ....................................
# [CV] ........ C=1, max_iter=100, tol=0.001, score=0.753, total=   0.0s
# [CV] C=1, max_iter=100, tol=0.01 .....................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [CV] ......... C=1, max_iter=100, tol=0.01, score=0.742, total=   0.0s
# [CV] C=1, max_iter=100, tol=0.01 .....................................
# [CV] ......... C=1, max_iter=100, tol=0.01, score=0.762, total=   0.0s
# [CV] C=1, max_iter=100, tol=0.01 .....................................
# [CV] ......... C=1, max_iter=100, tol=0.01, score=0.753, total=   0.0s
# [CV] C=1, max_iter=1000, tol=1e-05 ...................................
# [CV] ....... C=1, max_iter=1000, tol=1e-05, score=0.741, total=   0.0s
# [CV] C=1, max_iter=1000, tol=1e-05 ...................................
# [CV] ....... C=1, max_iter=1000, tol=1e-05, score=0.762, total=   0.0s
# [CV] C=1, max_iter=1000, tol=1e-05 ...................................
# [CV] ....... C=1, max_iter=1000, tol=1e-05, score=0.753, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.0001 ..................................
# [CV] ...... C=1, max_iter=1000, tol=0.0001, score=0.741, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.0001 ..................................
# [CV] ...... C=1, max_iter=1000, tol=0.0001, score=0.762, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.0001 ..................................
# [CV] ...... C=1, max_iter=1000, tol=0.0001, score=0.753, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.001 ...................................
# [CV] ....... C=1, max_iter=1000, tol=0.001, score=0.741, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.001 ...................................
# [CV] ....... C=1, max_iter=1000, tol=0.001, score=0.762, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.001 ...................................
# [CV] ....... C=1, max_iter=1000, tol=0.001, score=0.753, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.01 ....................................
# [CV] ........ C=1, max_iter=1000, tol=0.01, score=0.742, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.01 ....................................
# [CV] ........ C=1, max_iter=1000, tol=0.01, score=0.762, total=   0.0s
# [CV] C=1, max_iter=1000, tol=0.01 ....................................
# [CV] ........ C=1, max_iter=1000, tol=0.01, score=0.753, total=   0.0s
# [CV] C=5, max_iter=10, tol=1e-05 .....................................
# [CV] ......... C=5, max_iter=10, tol=1e-05, score=0.747, total=   0.0s
# [CV] C=5, max_iter=10, tol=1e-05 .....................................
# [CV] ......... C=5, max_iter=10, tol=1e-05, score=0.763, total=   0.0s
# [CV] C=5, max_iter=10, tol=1e-05 .....................................
# [CV] ......... C=5, max_iter=10, tol=1e-05, score=0.756, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.0001 ....................................
# [CV] ........ C=5, max_iter=10, tol=0.0001, score=0.747, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.0001 ....................................
# [CV] ........ C=5, max_iter=10, tol=0.0001, score=0.763, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.0001 ....................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ........ C=5, max_iter=10, tol=0.0001, score=0.756, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.001 .....................................
# [CV] ......... C=5, max_iter=10, tol=0.001, score=0.747, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.001 .....................................
# [CV] ......... C=5, max_iter=10, tol=0.001, score=0.763, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.001 .....................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ......... C=5, max_iter=10, tol=0.001, score=0.756, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.01 ......................................
# [CV] .......... C=5, max_iter=10, tol=0.01, score=0.747, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.01 ......................................
# [CV] .......... C=5, max_iter=10, tol=0.01, score=0.763, total=   0.0s
# [CV] C=5, max_iter=10, tol=0.01 ......................................
# [CV] .......... C=5, max_iter=10, tol=0.01, score=0.754, total=   0.0s
# [CV] C=5, max_iter=100, tol=1e-05 ....................................
# [CV] ........ C=5, max_iter=100, tol=1e-05, score=0.747, total=   0.0s
# [CV] C=5, max_iter=100, tol=1e-05 ....................................
# [CV] ........ C=5, max_iter=100, tol=1e-05, score=0.763, total=   0.0s
# [CV] C=5, max_iter=100, tol=1e-05 ....................................
# [CV] ........ C=5, max_iter=100, tol=1e-05, score=0.756, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.0001 ...................................
# [CV] ....... C=5, max_iter=100, tol=0.0001, score=0.747, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.0001 ...................................
# [CV] ....... C=5, max_iter=100, tol=0.0001, score=0.763, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.0001 ...................................
# [CV] ....... C=5, max_iter=100, tol=0.0001, score=0.756, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.001 ....................................
# [CV] ........ C=5, max_iter=100, tol=0.001, score=0.747, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.001 ....................................
# [CV] ........ C=5, max_iter=100, tol=0.001, score=0.763, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.001 ....................................
# [CV] ........ C=5, max_iter=100, tol=0.001, score=0.756, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.01 .....................................
# [CV] ......... C=5, max_iter=100, tol=0.01, score=0.747, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.01 .....................................
# [CV] ......... C=5, max_iter=100, tol=0.01, score=0.763, total=   0.0s
# [CV] C=5, max_iter=100, tol=0.01 .....................................
# [CV] ......... C=5, max_iter=100, tol=0.01, score=0.754, total=   0.0s
# [CV] C=5, max_iter=1000, tol=1e-05 ...................................
# [CV] ....... C=5, max_iter=1000, tol=1e-05, score=0.747, total=   0.0s
# [CV] C=5, max_iter=1000, tol=1e-05 ...................................
# [CV] ....... C=5, max_iter=1000, tol=1e-05, score=0.763, total=   0.0s
# [CV] C=5, max_iter=1000, tol=1e-05 ...................................
# [CV] ....... C=5, max_iter=1000, tol=1e-05, score=0.756, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.0001 ..................................
# [CV] ...... C=5, max_iter=1000, tol=0.0001, score=0.747, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.0001 ..................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ...... C=5, max_iter=1000, tol=0.0001, score=0.763, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.0001 ..................................
# [CV] ...... C=5, max_iter=1000, tol=0.0001, score=0.756, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.001 ...................................
# [CV] ....... C=5, max_iter=1000, tol=0.001, score=0.747, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.001 ...................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ....... C=5, max_iter=1000, tol=0.001, score=0.763, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.001 ...................................
# [CV] ....... C=5, max_iter=1000, tol=0.001, score=0.756, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.01 ....................................
# [CV] ........ C=5, max_iter=1000, tol=0.01, score=0.747, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.01 ....................................
# [CV] ........ C=5, max_iter=1000, tol=0.01, score=0.763, total=   0.0s
# [CV] C=5, max_iter=1000, tol=0.01 ....................................
# [CV] ........ C=5, max_iter=1000, tol=0.01, score=0.754, total=   0.0s
# [CV] C=10, max_iter=10, tol=1e-05 ....................................
# [CV] ........ C=10, max_iter=10, tol=1e-05, score=0.743, total=   0.0s
# [CV] C=10, max_iter=10, tol=1e-05 ....................................
# [CV] ........ C=10, max_iter=10, tol=1e-05, score=0.765, total=   0.0s
# [CV] C=10, max_iter=10, tol=1e-05 ....................................
# [CV] ........ C=10, max_iter=10, tol=1e-05, score=0.754, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.0001 ...................................
# [CV] ....... C=10, max_iter=10, tol=0.0001, score=0.743, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.0001 ...................................
# [CV] ....... C=10, max_iter=10, tol=0.0001, score=0.765, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.0001 ...................................
# [CV] ....... C=10, max_iter=10, tol=0.0001, score=0.754, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.001 ....................................
# [CV] ........ C=10, max_iter=10, tol=0.001, score=0.743, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.001 ....................................
# [CV] ........ C=10, max_iter=10, tol=0.001, score=0.765, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.001 ....................................
# [CV] ........ C=10, max_iter=10, tol=0.001, score=0.754, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.01 .....................................
# [CV] ......... C=10, max_iter=10, tol=0.01, score=0.744, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.01 .....................................
# [CV] ......... C=10, max_iter=10, tol=0.01, score=0.766, total=   0.0s
# [CV] C=10, max_iter=10, tol=0.01 .....................................
# [CV] ......... C=10, max_iter=10, tol=0.01, score=0.756, total=   0.0s
# [CV] C=10, max_iter=100, tol=1e-05 ...................................
# [CV] ....... C=10, max_iter=100, tol=1e-05, score=0.743, total=   0.0s
# [CV] C=10, max_iter=100, tol=1e-05 ...................................
# [CV] ....... C=10, max_iter=100, tol=1e-05, score=0.765, total=   0.0s
# [CV] C=10, max_iter=100, tol=1e-05 ...................................
# [CV] ....... C=10, max_iter=100, tol=1e-05, score=0.753, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.0001 ..................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ...... C=10, max_iter=100, tol=0.0001, score=0.743, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.0001 ..................................
# [CV] ...... C=10, max_iter=100, tol=0.0001, score=0.765, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.0001 ..................................
# [CV] ...... C=10, max_iter=100, tol=0.0001, score=0.753, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.001 ...................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ....... C=10, max_iter=100, tol=0.001, score=0.743, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.001 ...................................
# [CV] ....... C=10, max_iter=100, tol=0.001, score=0.765, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.001 ...................................
# [CV] ....... C=10, max_iter=100, tol=0.001, score=0.753, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.01 ....................................
# [CV] ........ C=10, max_iter=100, tol=0.01, score=0.744, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.01 ....................................
# [CV] ........ C=10, max_iter=100, tol=0.01, score=0.766, total=   0.0s
# [CV] C=10, max_iter=100, tol=0.01 ....................................
# [CV] ........ C=10, max_iter=100, tol=0.01, score=0.756, total=   0.0s
# [CV] C=10, max_iter=1000, tol=1e-05 ..................................
# [CV] ...... C=10, max_iter=1000, tol=1e-05, score=0.743, total=   0.0s
# [CV] C=10, max_iter=1000, tol=1e-05 ..................................
# [CV] ...... C=10, max_iter=1000, tol=1e-05, score=0.765, total=   0.0s
# [CV] C=10, max_iter=1000, tol=1e-05 ..................................
# [CV] ...... C=10, max_iter=1000, tol=1e-05, score=0.753, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.0001 .................................
# [CV] ..... C=10, max_iter=1000, tol=0.0001, score=0.743, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.0001 .................................
# [CV] ..... C=10, max_iter=1000, tol=0.0001, score=0.765, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.0001 .................................
# [CV] ..... C=10, max_iter=1000, tol=0.0001, score=0.753, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.001 ..................................
# [CV] ...... C=10, max_iter=1000, tol=0.001, score=0.743, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.001 ..................................
# [CV] ...... C=10, max_iter=1000, tol=0.001, score=0.765, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.001 ..................................
# [CV] ...... C=10, max_iter=1000, tol=0.001, score=0.753, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.01 ...................................
# [CV] ....... C=10, max_iter=1000, tol=0.01, score=0.744, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.01 ...................................
# [CV] ....... C=10, max_iter=1000, tol=0.01, score=0.766, total=   0.0s
# [CV] C=10, max_iter=1000, tol=0.01 ...................................
# [CV] ....... C=10, max_iter=1000, tol=0.01, score=0.756, total=   0.0s
# [CV] C=50, max_iter=10, tol=1e-05 ....................................
# [CV] ........ C=50, max_iter=10, tol=1e-05, score=0.749, total=   0.0s
# [CV] C=50, max_iter=10, tol=1e-05 ....................................
# [CV] ........ C=50, max_iter=10, tol=1e-05, score=0.773, total=   0.0s
# [CV] C=50, max_iter=10, tol=1e-05 ....................................
# [CV] ........ C=50, max_iter=10, tol=1e-05, score=0.755, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.0001 ...................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ....... C=50, max_iter=10, tol=0.0001, score=0.749, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.0001 ...................................
# [CV] ....... C=50, max_iter=10, tol=0.0001, score=0.773, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.0001 ...................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ....... C=50, max_iter=10, tol=0.0001, score=0.755, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.001 ....................................
# [CV] ........ C=50, max_iter=10, tol=0.001, score=0.749, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.001 ....................................
# [CV] ........ C=50, max_iter=10, tol=0.001, score=0.773, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.001 ....................................
# [CV] ........ C=50, max_iter=10, tol=0.001, score=0.755, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.01 .....................................
# [CV] ......... C=50, max_iter=10, tol=0.01, score=0.744, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.01 .....................................
# [CV] ......... C=50, max_iter=10, tol=0.01, score=0.769, total=   0.0s
# [CV] C=50, max_iter=10, tol=0.01 .....................................
# [CV] ......... C=50, max_iter=10, tol=0.01, score=0.756, total=   0.0s
# [CV] C=50, max_iter=100, tol=1e-05 ...................................
# [CV] ....... C=50, max_iter=100, tol=1e-05, score=0.749, total=   0.0s
# [CV] C=50, max_iter=100, tol=1e-05 ...................................
# [CV] ....... C=50, max_iter=100, tol=1e-05, score=0.775, total=   0.0s
# [CV] C=50, max_iter=100, tol=1e-05 ...................................
# [CV] ....... C=50, max_iter=100, tol=1e-05, score=0.755, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.0001 ..................................
# [CV] ...... C=50, max_iter=100, tol=0.0001, score=0.749, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.0001 ..................................
# [CV] ...... C=50, max_iter=100, tol=0.0001, score=0.775, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.0001 ..................................
# [CV] ...... C=50, max_iter=100, tol=0.0001, score=0.755, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.001 ...................................
# [CV] ....... C=50, max_iter=100, tol=0.001, score=0.749, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.001 ...................................
# [CV] ....... C=50, max_iter=100, tol=0.001, score=0.773, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.001 ...................................
# [CV] ....... C=50, max_iter=100, tol=0.001, score=0.756, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.01 ....................................
# [CV] ........ C=50, max_iter=100, tol=0.01, score=0.744, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.01 ....................................
# [CV] ........ C=50, max_iter=100, tol=0.01, score=0.769, total=   0.0s
# [CV] C=50, max_iter=100, tol=0.01 ....................................
# [CV] ........ C=50, max_iter=100, tol=0.01, score=0.756, total=   0.0s
# [CV] C=50, max_iter=1000, tol=1e-05 ..................................
# [CV] ...... C=50, max_iter=1000, tol=1e-05, score=0.749, total=   0.0s
# [CV] C=50, max_iter=1000, tol=1e-05 ..................................
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [CV] ...... C=50, max_iter=1000, tol=1e-05, score=0.775, total=   0.0s
# [CV] C=50, max_iter=1000, tol=1e-05 ..................................
# [CV] ...... C=50, max_iter=1000, tol=1e-05, score=0.755, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.0001 .................................
# [CV] ..... C=50, max_iter=1000, tol=0.0001, score=0.749, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.0001 .................................
# [CV] ..... C=50, max_iter=1000, tol=0.0001, score=0.775, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.0001 .................................
# [CV] ..... C=50, max_iter=1000, tol=0.0001, score=0.755, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.001 ..................................
# [CV] ...... C=50, max_iter=1000, tol=0.001, score=0.749, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.001 ..................................
# [CV] ...... C=50, max_iter=1000, tol=0.001, score=0.773, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.001 ..................................
# [CV] ...... C=50, max_iter=1000, tol=0.001, score=0.756, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.01 ...................................
# [CV] ....... C=50, max_iter=1000, tol=0.01, score=0.744, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.01 ...................................
# [CV] ....... C=50, max_iter=1000, tol=0.01, score=0.769, total=   0.0s
# [CV] C=50, max_iter=1000, tol=0.01 ...................................
# [CV] ....... C=50, max_iter=1000, tol=0.01, score=0.756, total=   0.0s
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=1)]: Done 144 out of 144 | elapsed:    1.1s finished
# C:\Users\dutch\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=LogisticRegression(C=50, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='warn',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='warn',
#                                           tol=1e-05, verbose=0,
#                                           warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [1, 5, 10, 50], 'max_iter': [10, 100, 1000],
#                          'tol': [1e-05, 0.0001, 0.001, 0.01]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 50, 'max_iter': 100, 'tol': 1e-05}
# 0.7594268476621417

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["Non Candidate", "Candidate"]))
# Out:
#                precision    recall  f1-score   support
#
# Non Candidate       0.68      0.68      0.68       450
#     Candidate       0.83      0.83      0.83       876
#
#      accuracy                           0.78      1326
#     macro avg       0.76      0.76      0.76      1326
#  weighted avg       0.78      0.78      0.78      1326

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'avr_logical_regression.sav'
joblib.dump(model, filename)
# Out:
# ['avr_logical_regression.sav']
